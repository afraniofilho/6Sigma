# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/6Sigma/blob/main/LOC_e_ILOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cars = {'Brand' : ['Honda Civic', 'Toyota Corolla', 'Ford Focus', 'Audi A4'],
        'Price' : [22000, 25000, 27000, 35000],
        'Quality': [800, 750, 900, 900]}

# %%
type(cars)
# Out:
# dict

# %%
import pandas as pd

# %%
df = pd.DataFrame(cars, columns = ['Brand', 'Price', 'Quality'])

# %%
df
# Out:
#             Brand  Price  Quality
# 0     Honda Civic  22000      800
# 1  Toyota Corolla  25000      750
# 2      Ford Focus  27000      900
# 3         Audi A4  35000      900

# %%
df.loc[0, 'Brand']
# Out:
# 'Honda Civic'

# %%
df.loc[0]
# Out:
# Brand      Honda Civic
# Price            22000
# Quality            800
# Name: 0, dtype: object

# %%
df
# Out:
#             Brand  Price  Quality
# 0     Honda Civic  22000      800
# 1  Toyota Corolla  25000      750
# 2      Ford Focus  27000      900
# 3         Audi A4  35000      900

# %%
df2 = df.loc[2:3, ['Brand', 'Quality']]

# %%
df2
# Out:
#         Brand  Quality
# 2  Ford Focus      900
# 3     Audi A4      900

# %%
# Selecionar os registros com 'Quality' > 800

# %%
df3 = df.loc[df['Quality'] > 800]

# %%
df3
# Out:
#         Brand  Price  Quality
# 2  Ford Focus  27000      900
# 3     Audi A4  35000      900

# %%
# Selecionar os registros em que o 'Price'seja maior do que 30000 e o 'Quality' seja maior do que 800

# %%
df4 = df.loc[(df['Price'] > 30000) & (df['Quality'] > 800)]

# %%
df4
# Out:
#      Brand  Price  Quality
# 3  Audi A4  35000      900

# %%
df
# Out:
#             Brand  Price  Quality
# 0     Honda Civic  22000      800
# 1  Toyota Corolla  25000      750
# 2      Ford Focus  27000      900
# 3         Audi A4  35000      900

# %%
# Selecionar os registros em que o 'Brand'seja 'Ford Focus'ou 'Toyota Corolla'

# %%
df.loc[(df['Brand'] == 'Ford Focus') | (df['Brand'] == 'Toyota Corolla') & (df['Quality'] > 800)]
# Out:
#         Brand  Price  Quality
# 2  Ford Focus  27000      900

# %%
df.loc[df.Brand == 'Ford Focus', 'Quality']
# Out:
# 2    900
# Name: Quality, dtype: int64

# %%
df
# Out:
#             Brand  Price  Quality
# 0     Honda Civic  22000      800
# 1  Toyota Corolla  25000      750
# 2      Ford Focus  27000      900
# 3         Audi A4  35000      900

# %%
df.iloc[1,2]
# Out:
# 750

# %%
df.iloc[3]
# Out:
# Brand      Audi A4
# Price        35000
# Quality        900
# Name: 3, dtype: object

# %%
df
# Out:
#             Brand  Price  Quality
# 0     Honda Civic  22000      800
# 1  Toyota Corolla  25000      750
# 2      Ford Focus  27000      900
# 3         Audi A4  35000      900

# %%
df.drop(1, inplace = True)

# %%
df
# Out:
#          Brand  Price  Quality
# 0  Honda Civic  22000      800
# 2   Ford Focus  27000      900
# 3      Audi A4  35000      900

# %%
df.iloc[1]
# Out:
# Brand      Ford Focus
# Price           27000
# Quality           900
# Name: 2, dtype: object

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#          Brand  Price  Quality
# 0  Honda Civic  22000      800
# 1   Ford Focus  27000      900
# 2      Audi A4  35000      900

# %%
df.loc[2]
# Out:
# Brand      Audi A4
# Price        35000
# Quality        900
# Name: 2, dtype: object
