# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/6Sigma/blob/main/Untitled57.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tickers = '^BVSP USDBRL=X'

# %%
tickers
# Out:
# '^BVSP USDBRL=X'

# %%
carteira = yf.download(tickers, start='2007-01-01')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
carteira.head()
# Out:
#            Adj Close             Close              High               Low  \
#             USDBRL=X    ^BVSP USDBRL=X    ^BVSP USDBRL=X    ^BVSP USDBRL=X
# Date
# 2007-01-01    2.1325      NaN   2.1325      NaN   2.1325      NaN   2.1310
# 2007-01-02    2.1310  45383.0   2.1310  45383.0   2.1432  45388.0   2.1295
# 2007-01-03    2.1345  44445.0   2.1345  44445.0   2.1351  45379.0   2.1278
# 2007-01-04    2.1390  44020.0   2.1390  44020.0   2.1430  44442.0   2.1345
# 2007-01-05    2.1470  42245.0   2.1470  42245.0   2.1525  44081.0   2.1345
#
#                         Open            Volume
#               ^BVSP USDBRL=X    ^BVSP USDBRL=X        ^BVSP
# Date
# 2007-01-01      NaN   2.1310      NaN      0.0          NaN
# 2007-01-02  44476.0   2.1335  44476.0      0.0   75560200.0
# 2007-01-03  44284.0   2.1310  45379.0      0.0  122372800.0
# 2007-01-04  43623.0   2.1345  44442.0      0.0   86577000.0
# 2007-01-05  42160.0   2.1390  44019.0      0.0  164055000.0

# %%
carteira.shape
# Out:
# (4314, 12)

# %%
carteira.tail()
# Out:
#            Adj Close                   Close                     High  \
#             USDBRL=X          ^BVSP USDBRL=X          ^BVSP  USDBRL=X
# Date
# 2023-07-12    4.8515  117666.000000   4.8515  117666.000000  4.858400
# 2023-07-13    4.8169  119264.000000   4.8169  119264.000000  4.822762
# 2023-07-14    4.7948  117711.000000   4.7948  117711.000000  4.806300
# 2023-07-17    4.7881  118219.460938   4.7881  118219.460938  4.847000
# 2023-07-18    4.8073            NaN   4.8073            NaN  4.807300
#
#                                Low                    Open                 \
#                    ^BVSP  USDBRL=X          ^BVSP USDBRL=X          ^BVSP
# Date
# 2023-07-12  119156.00000  4.783000  117557.000000   4.8515  117557.000000
# 2023-07-13  119739.00000  4.779804  117668.000000   4.8169  117671.000000
# 2023-07-14  119329.00000  4.771745  117526.000000   4.7948  119268.000000
# 2023-07-17  118302.34375  4.772341  116591.117188   4.7881  117710.539062
# ...

# %%
carteira['Close'].plot(subplots=True, figsize=(22,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)
