# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/6Sigma/blob/main/YFinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 20.5 MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23918 sha256=bd2bbcb4bc7bfacc49f85386c9cba634014d67593983edce888dff6d031031c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gj9sp6xy/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import plotly.express as px

# %%
tickers = '^BVSP'

# %%
tickers
# Out:
# '^BVSP'

# %%
carteira = yf.download(tickers, start='2007-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
carteira.head()
# Out:
#                Open     High      Low    Close  Adj Close     Volume
# Date
# 2007-01-02  44476.0  45388.0  44476.0  45383.0    45383.0   75560200
# 2007-01-03  45379.0  45379.0  44284.0  44445.0    44445.0  122372800
# 2007-01-04  44442.0  44442.0  43623.0  44020.0    44020.0   86577000
# 2007-01-05  44019.0  44081.0  42160.0  42245.0    42245.0  164055000
# 2007-01-08  42249.0  42926.0  42144.0  42830.0    42830.0  114007100

# %%
carteira.shape
# Out:
# (3845, 12)

# %%
sns.set()

# %%
carteira['Close'].plot(subplots=True, figsize=(22,8));

# %%
fig = px.line(carteira, x=carteira.index, y="Close", title='Quote')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="83ce28be-0100-44bf-a148-32a38fac3746" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83ce28be-0100-44bf-a148-32a38fac3746")) {
#                     Plotly.newPlot(
#                         '83ce28be-0100-44bf-a148-32a38fac3746',
# ...
